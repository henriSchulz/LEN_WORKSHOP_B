# %% [markdown]
# # Spannungverhältnis $\frac{\underline{U}_2}{\underline{U}_1}$
# <img src="CleanShot 2025-01-29 at 22.18.47@2x.png">

# %%
from sympy import *

R, L, C, omega = symbols("R L C omega", real=True)

U_2 = 1/(I + omega * C)

U_1 = R + 1/(I * omega * C)  + I * omega * L

ratio = expand(U_2 / U_1)

im_ratio = ratio.as_real_imag()[1]
re_ratio = ratio.as_real_imag()[0]


solve(im_ratio-re_ratio, omega)[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      11 im_ratio = ratio.as_real_imag()[1]
#      12 re_ratio = ratio.as_real_imag()[0]
# ---> 15 solve(im_ratio-re_ratio, omega)[1]
#
# File ~/PycharmProjects/LEN_WORKSHOP_B/.venv/lib/python3.12/site-packages/sympy/solvers/solvers.py:1170, in solve(f, *symbols, **flags)
#    1168         solution = _solve_undetermined(f[0], symbols, flags)
#    1169     if not solution:
# -> 1170         solution = _solve(f[0], *symbols, **flags)
#    1171 else:
#    1172     linear, solution = _solve_system(f, symbols, **flags)
#
# File ~/PycharmProjects/LEN_WORKSHOP_B/.venv/lib/python3.12/site-packages/sympy/solvers/solvers.py:1746, in _solve(f, *symbols, **flags)
#    1741 if checkdens:
#    1742     # reject any result that makes any denom. affirmatively 0;
#    1743     # if in doubt, keep it
# ...
